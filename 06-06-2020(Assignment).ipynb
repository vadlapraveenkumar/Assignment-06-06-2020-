# %% [markdown]
# ## Cse-221710309059-v praveen kumar

# %%
# The link used: https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv

# %%
# For the data


import pandas as pd
import numpy as np

df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv")
df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 10 columns]

# %%
#answer 1

#for removing unnamed column

df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv",index_col=0)
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose
# 0           6             radio/TV
# 1          48             radio/TV
# 2          12            education
# 3          42  furniture/equipment
# 4          24                  car
# ..        ...                  ...
# 995        12  furniture/equipment
# 996        30                  car
# 997        12             radio/TV
# 998        45             radio/TV
# 999        45                  car
#
# [1000 rows x 9 columns]

# %%
#answer 2

df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv",nrows=7)
print(df)
df.tail(3)
print(df)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car
# 5           9055        36            education
# 6           2835        24  furniture/equipment
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car
# 5           9055        36            education
# 6           2835        24  furniture/equipment

# %%
#answer 3

index=df.index
rows=len(index)
print("total no of entries:",rows)
# Out:
# total no of entries: 7

# %%
#answer 4


print("No of features:",len(df.columns))
for col in df.columns:
    print(col)
# Out:
# No of features: 10
# Unnamed: 0
# Age
# Sex
# Job
# Housing
# Saving accounts
# Checking account
# Credit amount
# Duration
# Purpose

# %%
#answer 5


for row in df.index:
    print(row)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#answer 6

df.dtypes
# Out:
# Unnamed: 0           int64
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
#answer 7

df.describe().tail(6)
# Out:
#      Unnamed: 0        Age      Job  Credit amount   Duration
# std    2.160247  14.407339  0.48795    2979.959252  15.436506
# min    0.000000  22.000000  1.00000    1169.000000   6.000000
# 25%    1.500000  40.000000  1.50000    2465.500000  18.000000
# 50%    3.000000  49.000000  2.00000    4870.000000  24.000000
# 75%    4.500000  53.000000  2.00000    6916.500000  39.000000
# max    6.000000  67.000000  2.00000    9055.000000  48.000000

# %%
#answer 8

# Description for the categorical Columns count,top,freq


df.describe(include = ['O']).drop(['unique'])
# Out:
#         Sex Housing Saving accounts Checking account    Purpose
# count     7       7               5                4          7
# top    male     own          little           little  education
# freq      6       4               4                3          2

# %%
#answer 9

df.isnull().sum()
# Out:
# Unnamed: 0          0
# Age                 0
# Sex                 0
# Job                 0
# Housing             0
# Saving accounts     2
# Checking account    3
# Credit amount       0
# Duration            0
# Purpose             0
# dtype: int64

# %%
#answer 10

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
# Unnamed: 0          7 non-null int64
# Age                 7 non-null int64
# Sex                 7 non-null object
# Job                 7 non-null int64
# Housing             7 non-null object
# Saving accounts     5 non-null object
# Checking account    4 non-null object
# Credit amount       7 non-null int64
# Duration            7 non-null int64
# Purpose             7 non-null object
# dtypes: int64(5), object(5)
# memory usage: 688.0+ bytes

# %%
#answer 11

#loc
df.loc[:,"Age"]
df


#iloc
df.iloc[:2]
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
#
#    Credit amount  Duration   Purpose
# 0           1169         6  radio/TV
# 1           5951        48  radio/TV

# %%
#answer 12
#no of unique values

len(df.Housing.unique())
# Out:
# 2
